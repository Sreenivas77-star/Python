# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenivas77-star/Python/blob/main/NP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)
y = np.tan(x)
plt.plot(x,y)
